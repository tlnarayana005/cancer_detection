# %% [markdown]
# # Data Exploration
#
# This notebook is a starter exploration for the medical image dataset used in the cancer detection project.

# %%
import pathlib
import pandas as pd
from PIL import Image
